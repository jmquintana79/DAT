# %% [markdown]
# # EDA: describe
#
# Es una ampliacion de la informacion descriptiva del metodo *describe()* de *Pandas*.

# %%
# %matplotlib inline
import sys
sys.path.append('../../') 
import warnings
warnings.filterwarnings('ignore')
from sklearn.datasets import load_iris
import pandas as pd
pd.options.display.max_rows = 999
pd.options.display.max_columns = 99
import numpy as np
from datetime import datetime
from eda import describe_info, describe_numeric, describe_categorical, describe_datetime, describe_bivariate, describe_missing, describe_duplicates, describe_outliers

# %% [markdown]
# ---
# ## load *Tips* data

# %%
import seaborn
data = seaborn.load_dataset('tips')
data.shape
# Out:
# (244, 7)

# %% [markdown]
# ### general info

# %%
describe_info(data)
# Out:
#                types mixed_types  unique  magnitude  %nan  num_records
# variable
# sex         category         str       2        NaN   0.0          244
# smoker      category         str       2        NaN   0.0          244
# day         category         str       4        NaN   0.0          244
# time        category         str       2        NaN   0.0          244
# total_bill   float64       float     229        1.0   0.0          244
# tip          float64       float     123        0.0   0.0          244
# size           int64         int       6        0.0   0.0          244

# %% [markdown]
# ### numerical

# %%
# describe
dfn = describe_numeric(data, alpha = .05)
dfn
# Out:
# [info] Function "describe_numeric()" finished in 2.45 seconds.
#             count   mode  mode_per   mean   std    iqr   min    5%    25%  \
# total_bill    244  13.42      1.23  19.79  8.90  10.78  3.07  9.56  13.35
# tip           244   2.00     13.52   3.00  1.38   1.56  1.00  1.44   2.00
# size          244   2.00     63.93   2.57  0.95   1.00  1.00  2.00   2.00
#
#              50%    75%    95%    max  kurtosis  skew  uniform  gaussian  \
# total_bill  17.8  24.13  38.06  50.81      1.17  1.13    False     False
# tip          2.9   3.56   5.20  10.00      3.55  1.46    False     False
# size         2.0   3.00   4.00   6.00      1.67  1.44    False     False
#
#              expo  unimodal
# total_bill  False      True
# tip         False     False
# size        False     False

# %% [markdown]
# ### categorical

# %%
# describe
dfc = describe_categorical(data, max_size_cats = 6, alpha = .05)
dfc
# Out:
# [info] Function "describe_categorical()" finished in 0.05 seconds.
#        count unique  uniform  value0  value1 value2 value3 value4 value5  \
# var
# sex      244      2    False    Male  Female
# smoker   244      2    False      No     Yes
# day      244      4    False     Sat     Sun   Thur    Fri
# time     244      2    False  Dinner   Lunch
# size     244      6    False       2       3      4      5      6      1
#
#        %value0 %value1 %value2 %value3 %value4 %value5
# var
# sex      64.34   35.66
# smoker   61.89   38.11
# day      35.66   31.15   25.41    7.79
# time     72.13   27.87
# size     63.93   15.57   15.16    2.05    1.64    1.64

# %% [markdown]
# ### bivariate relationship

# %%
describe_bivariate(data)
# Out:
# [info] it was simplified the categorical variable 'size'.
# [info] Function "describe_bivariate()" finished in 0.56 seconds.
#     variable1   variable2 depend_corr_linear  corr_linear  corr_non_linear  \
# 0  total_bill         tip               True         0.62             0.46
# 0         sex      smoker                NaN          NaN              NaN
# 1         sex         day                NaN          NaN              NaN
# 2         sex        time                NaN          NaN              NaN
# 3         sex        size                NaN          NaN              NaN
# 4      smoker         day                NaN          NaN              NaN
# 5      smoker        time                NaN          NaN              NaN
# 6      smoker        size                NaN          NaN              NaN
# 7         day        time                NaN          NaN              NaN
# 8         day        size                NaN          NaN              NaN
# 9        time        size                NaN          NaN              NaN
# 0         day         tip                NaN          NaN              NaN
# 1         day  total_bill                NaN          NaN              NaN
# 2         sex         tip                NaN          NaN              NaN
# 3         sex  total_bill                NaN          NaN              NaN
# 4        size         tip                NaN          NaN              NaN
# 5        size  total_bill                NaN          NaN              NaN
# 6      smoker         tip                NaN          NaN              NaN
# 7      smoker  total_bill                NaN          NaN              NaN
# 8        time         tip                NaN          NaN              NaN
# 9        time  total_bill                NaN          NaN              NaN
#
#   depend_chi2 subsamples_diff_dist
# 0         NaN                  NaN
# 0       False                  NaN
# 1        True                  NaN
# 2        True                  NaN
# 3       False                  NaN
# 4        True                  NaN
# 5       False                  NaN
# 6       False                  NaN
# 7        True                  NaN
# 8        True                  NaN
# 9        True                  NaN
# 0         NaN                 True
# 1         NaN                 True
# 2         NaN                False
# 3         NaN                False
# 4         NaN                 True
# 5         NaN                 True
# 6         NaN                False
# 7         NaN                False
# 8         NaN                False
# 9         NaN                 True

# %% [markdown]
# ### missing values

# %%
describe_missing(data)

# %% [markdown]
# ### outliers analysis

# %%
describe_outliers(data)

# %% [markdown]
# ### duplicates

# %%
describe_duplicates(data)
# Out:
# [info] Function "describe_duplicates()" finished in 0.04 seconds.
#       col0    col1  col2  col3  col4  num_cols  percent_dupli
# 30     sex  smoker   day  time  size         5      77.459016
# 25     sex  smoker   day  time               4      91.803279
# 29  smoker     day  time  size               4      86.475410
# 27     sex  smoker  time  size               4      86.065574
# 28     sex     day  time  size               4      86.065574
# 26     sex  smoker   day  size               4      78.688525
# 16     sex  smoker  time                     3      96.721311
# 18     sex     day  time                     3      95.491803
# 21  smoker     day  time                     3      95.491803
# 15     sex  smoker   day                     3      93.442623
# 17     sex  smoker  size                     3      92.213115
# 20     sex    time  size                     3      92.213115
# 23  smoker    time  size                     3      92.213115
# 24     day    time  size                     3      91.393443
# 19     sex     day  size                     3      87.295082
# 22  smoker     day  size                     3      87.295082
# 5      sex  smoker                           2      98.360656
# 7      sex    time                           2      98.360656
# 10  smoker    time                           2      98.360656
# 12     day    time                           2      97.540984
# 6      sex     day                           2      96.721311
# 9   smoker     day                           2      96.721311
# 8      sex    size                           2      95.901639
# 11  smoker    size                           2      95.901639
# 14    time    size                           2      95.901639
# 13     day    size                           2      92.213115
# 0      sex                                   1      99.180328
# 1   smoker                                   1      99.180328
# 3     time                                   1      99.180328
# 2      day                                   1      98.360656
# 4     size                                   1      97.950820
