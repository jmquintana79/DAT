# %% [markdown]
# # EDA

# %%
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
from sklearn.datasets import load_iris
import pandas as pd
pd.options.display.max_rows = 999
pd.options.display.max_columns = 99
from datetime import datetime
from DAT import EDA
eda = EDA()

# %% [markdown]
# ---
# ## LOAD *SunPlots* data

# %%
url_data = "https://raw.githubusercontent.com/jmquintana79/Datasets/master/monthly-sunspots.csv"
data = pd.read_csv(url_data, sep = ',')
data["Month_dt"] = data["Month"].apply(lambda x: datetime.strptime(x, '%Y-%m'))
data.shape
# Out:
# (2820, 3)

# %% [markdown]
# ### general info

# %%
eda.info(data)
# Out:
#                    types                               mixed_types  unique  \
# variable
# Month_dt  datetime64[ns]  pandas._libs.tslibs.timestamps.Timestamp    2820
# Sunspots         float64                                     float    1140
# Month             object                                       str    2820
#
#           magnitude  %nan  num_records
# variable
# Month_dt        NaN   0.0         2820
# Sunspots        1.0   0.0         2820
# Month           NaN   0.0         2820

# %% [markdown]
# ### summary

# %%
eda.summary(data)
# Out:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 2820   │ │ string      │ 1     │                                                          │
# │ │ Number of columns │ 3      │ │ float64     │ 1     │                                                          │
# │ └───────────────────┴────────┘ │ datetime64  │ 1     │                                                          │
# ...

# %% [markdown]
# ### numerical

# %%
# describe
dfn = eda.numeric(data)
dfn
# Out:
# INFO: Function "numeric()" finished in 0.18 seconds.
#           count  mode  mode_per   mean    std  std_norm    iqr  min   5%  \
# Sunspots   2820   0.0      2.38  51.27  43.45      0.85  59.23  0.0  1.7
#
#            25%   50%    75%    95%    max  kurtosis  skew  uniform  gaussian  \
# Sunspots  15.7  42.0  74.93  138.2  253.8      0.98   1.1    False     False
#
#           unimodal
# Sunspots      True

# %% [markdown]
# ### categorical

# %%
# describe
dfc = eda.categorical(data, max_size_cats = 3, alpha = .05)
dfc
# Out:
# INFO: Function "categorical()" finished in 0.45 seconds.
#       count unique  uniform   value0   value1  value2 %value0 %value1 %value2
# Month  2820   2820     True  1749-01  1895-12  others    0.04    0.04    0.12

# %% [markdown]
# ### temporal columns

# %%
eda.temporal(data)
# Out:
#          count unique most_frequent num_most_frequent      first       last  \
# Month_dt  2820   2820           NaT               NaN 1749-01-01 1983-12-01
#
#              most_frequent_td  %most_frequent_td  num_td
# Month_dt  (31 days 00:00:00,)              58.32       4

# %% [markdown]
# ### bivariate relationship

# %%
eda.bivariate(data)
# Out:
# INFO: It was simplified the categorical variable 'Month'.
# WARNING: It was not possible estimate Maximum Bhattacharyya distance for ['Month', 'Sunspots'].
# INFO: Function "bivariate()" finished in 0.23 seconds.
#   variable1 variable2 depend_corr_linear corr_linear corr_non_linear pps12  \
# 0     Month  Sunspots                NaN         NaN             NaN     0
#
#   pps21 depend_chi2 subsamples_diff_dist  max_bhatta_dist
# 0     0         NaN                False              NaN

# %% [markdown]
# ### missing values

# %%
eda.missing(data)
# Out:
# INFO: There are not any missing values.

# %% [markdown]
# ### outliers analysis

# %%
eda.outliers(data)

# %% [markdown]
# ### duplicates

# %%
eda.duplicates(data, subset=[])
# Out:
# INFO: Number of duplicates for subset ['Month'] = 0 / 0.0 %
# INFO: Number of duplicates for subset ['Sunspots'] = 1736 / 61.56 %
# INFO: Number of duplicates for subset ['Month_dt'] = 0 / 0.0 %
# INFO: Number of duplicates for ALL columns = 0 / 0.0 %
# INFO: Number of duplicates for subset ['Sunspots'] = 1736 / 61.56 %
