# %% [markdown]
# # EDA

# %%
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
from sklearn.datasets import load_iris
import pandas as pd
pd.options.display.max_rows = 999
pd.options.display.max_columns = 99
from DAT import EDA
eda = EDA()

# %% [markdown]
# ---
# ## LOAD *Titanic* data

# %%
import seaborn
data = seaborn.load_dataset('titanic')
data.shape
# Out:
# (891, 15)

# %% [markdown]
# ### general info

# %%
eda.info(data)
# Out:
#                 types mixed_types  unique  magnitude   %nan  num_records
# variable
# adult_male       bool        bool       2        NaN   0.00          891
# alone            bool        bool       2        NaN   0.00          891
# class        category         str       3        NaN   0.00          891
# deck         category         str       7        NaN  77.22          203
# age           float64       float      88        1.0  19.87          714
# fare          float64       float     248        1.0   0.00          891
# survived        int64         int       2        0.0   0.00          891
# pclass          int64         int       3        0.0   0.00          891
# sibsp           int64         int       7        0.0   0.00          891
# parch           int64         int       7        0.0   0.00          891
# sex            object         str       2        NaN   0.00          891
# embarked       object         str       3        NaN   0.22          889
# who            object         str       3        NaN   0.00          891
# embark_town    object         str       3        NaN   0.22          889
# alive          object         str       2        NaN   0.00          891

# %% [markdown]
# ### summary

# %%
eda.summary(data)
# Out:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types               Categories                                        │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓ ┏━━━━━━━━━━━━━━━━━━━━━━━┓                                │
# │ ┃ dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃ ┃ Categorical Variables ┃                                │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩ ┡━━━━━━━━━━━━━━━━━━━━━━━┩                                │
# │ │ Number of rows    │ 891    │ │ string      │ 5     │ │ class                 │                                │
# │ │ Number of columns │ 15     │ │ int64       │ 4     │ │ deck                  │                                │
# │ └───────────────────┴────────┘ │ float64     │ 2     │ └───────────────────────┘                                │
# │                                │ category    │ 2     │                                                          │
# │                                │ bool        │ 2     │                                                          │
# │                                └─────────────┴───────┘                                                          │
# │                                                     number                                                      │
# │ ┏━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━┓  │
# │ ┃ column_name        ┃ NA     ┃ NA %    ┃ mean    ┃ sd      ┃ p0      ┃ p25    ┃ p75    ┃ p100    ┃ hist     ┃  │
# │ ┡━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━╇━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━┩  │
# │ │ survived           │      0 │       0 │    0.38 │    0.49 │       0 │      0 │      1 │       1 │  █    ▅  │  │
# │ │ pclass             │      0 │       0 │     2.3 │    0.84 │       1 │      2 │      3 │       3 │  ▄  ▃ █  │  │
# │ │ age                │    180 │      20 │      30 │      15 │    0.42 │     20 │     38 │      80 │  ▂██▃▁   │  │
# │ │ sibsp              │      0 │       0 │    0.52 │     1.1 │       0 │      0 │      1 │       8 │    █     │  │
# │ │ parch              │      0 │       0 │    0.38 │    0.81 │       0 │      0 │      0 │       6 │   █▁▁    │  │
# │ │ fare               │      0 │       0 │      32 │      50 │       0 │    7.9 │     31 │     510 │    █     │  │
# │ └────────────────────┴────────┴─────────┴─────────┴─────────┴─────────┴────────┴────────┴─────────┴──────────┘  │
# │                                                    category                                                     │
# │ ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓  │
# │ ┃ column_name                     ┃ NA          ┃ NA %           ┃ ordered               ┃ unique            ┃  │
# │ ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩  │
# │ │ class                           │           0 │              0 │ False                 │                 3 │  │
# │ │ deck                            │         690 │             77 │ False                 │                 8 │  │
# │ └─────────────────────────────────┴─────────────┴────────────────┴───────────────────────┴───────────────────┘  │
# │                                                     string                                                      │
# │ ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━┓  │
# │ ┃ column_name               ┃ NA      ┃ NA %       ┃ words per row                ┃ total words              ┃  │
# │ ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━┩  │
# │ │ sex                       │       0 │          0 │                            1 │                      890 │  │
# │ │ embarked                  │       2 │       0.22 │                            1 │                      890 │  │
# │ │ who                       │       0 │          0 │                            1 │                      890 │  │
# │ │ embark_town               │       2 │       0.22 │                            1 │                      890 │  │
# │ │ alive                     │       0 │          0 │                            1 │                      890 │  │
# │ └───────────────────────────┴─────────┴────────────┴──────────────────────────────┴──────────────────────────┘  │
# │                                                      bool                                                       │
# │ ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┓  │
# │ ┃ column_name                        ┃ true            ┃ true rate                     ┃ hist                ┃  │
# │ ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━┩  │
# │ │ adult_male                         │             540 │                           0.6 │       ▅    █        │  │
# │ │ alone                              │             540 │                           0.6 │       ▅    █        │  │
# │ └────────────────────────────────────┴─────────────────┴───────────────────────────────┴─────────────────────┘  │
# ╰────────────────────────────────────────────────────── End ──────────────────────────────────────────────────────╯

# %% [markdown]
# ### numerical

# %%
# describe
dfn = eda.numeric(data)
dfn
# Out:
# INFO: Function "numeric()" finished in 0.16 seconds.
#           count   mode  mode_per   mean    std  std_norm    iqr   min    5%  \
# survived    891   0.00     61.62   0.38   0.49      1.27   1.00  0.00  0.00
# pclass      891   3.00     55.11   2.31   0.84      0.36   1.00  1.00  1.00
# age         714  24.00      4.20  29.70  14.53      0.49  17.88  0.42  4.00
# sibsp       891   0.00     68.24   0.52   1.10      2.11   1.00  0.00  0.00
# parch       891   0.00     76.09   0.38   0.81      2.11   0.00  0.00  0.00
# fare        891   8.05      4.83  32.20  49.69      1.54  23.09  0.00  7.22
#
#             25%    50%   75%     95%     max  kurtosis  skew  uniform  \
# survived   0.00   0.00   1.0    1.00    1.00     -1.77  0.48    False
# pclass     2.00   3.00   3.0    3.00    3.00     -1.28 -0.63    False
# age       20.12  28.00  38.0   56.00   80.00      0.17  0.39    False
# sibsp      0.00   0.00   1.0    3.00    8.00     17.77  3.69    False
# parch      0.00   0.00   0.0    2.00    6.00      9.72  2.74    False
# fare       7.91  14.45  31.0  112.08  512.33     33.20  4.78    False
#
#           gaussian  unimodal
# survived     False     False
# pclass       False     False
# age          False     False
# sibsp        False     False
# parch        False     False
# fare         False     False

# %% [markdown]
# ### categorical

# %%
# describe
dfc = eda.categorical(data, max_size_cats = 3, alpha = .05)
dfc
# Out:
# INFO: Function "categorical()" finished in 0.06 seconds.
#             count unique  uniform       value0     value1      value2 %value0  \
# survived      891      2    False            0          1               61.62
# pclass        891      3    False            3          1           2   55.11
# sex           891      2    False         male     female               64.76
# sibsp         891      7    False            0          1      others   68.24
# parch         891      7    False            0          1      others   76.09
# embarked      889      3    False            S          C           Q   72.44
# class         891      3    False        Third      First      Second   55.11
# who           891      3    False          man      woman       child   60.27
# adult_male    891      2    False         True      False               60.27
# deck          203      7    False            C          B      others   29.06
# embark_town   889      3    False  Southampton  Cherbourg  Queenstown   72.44
# alive         891      2    False           no        yes               61.62
# alone         891      2    False         True      False               60.27
#
#             %value1 %value2
# survived      38.38
# pclass        24.24   20.65
# sex           35.24
# sibsp         23.46    3.15
# parch         13.24    1.12
# embarked       18.9    8.66
# class         24.24   20.65
# who           30.42    9.32
# adult_male    39.73
# deck          23.15   15.76
# embark_town    18.9    8.66
# alive         38.38
# alone         39.73

# %% [markdown]
# ### temporal columns

# %%
eda.temporal(data)
# Out:
# WARNING: There are not any datetime column.

# %% [markdown]
# ### bivariate relationship

# %%
eda.bivariate(data)
# Out:
# INFO: It was simplified the categorical variable 'sibsp'.
# INFO: It was simplified the categorical variable 'parch'.
# INFO: It was simplified the categorical variable 'deck'.
# WARNING: It was not possible estimate Maximum Bhattacharyya distance for ['alive', 'survived'].
# WARNING: It was not possible estimate Maximum Bhattacharyya distance for ['class', 'pclass'].
# WARNING: It was not possible estimate Maximum Bhattacharyya distance for ['deck', 'pclass'].
# INFO: Function "bivariate()" finished in 12.62 seconds.
#       variable1    variable2 depend_corr_linear  corr_linear  corr_non_linear  \
# 0      survived       pclass               True        -0.32             0.08
# 1      survived          age              False        -0.03             0.09
# 2      survived         fare               True         0.17             0.28
# 3        pclass          age               True        -0.29             0.17
# 4        pclass         fare               True        -0.53             0.92
# 5           age         fare               True         0.10             0.20
# 0      survived       pclass                NaN          NaN              NaN
# 1      survived          sex                NaN          NaN              NaN
# 2      survived        sibsp                NaN          NaN              NaN
# 3      survived        parch                NaN          NaN              NaN
# 4      survived     embarked                NaN          NaN              NaN
# 5      survived        class                NaN          NaN              NaN
# 6      survived          who                NaN          NaN              NaN
# 7      survived   adult_male                NaN          NaN              NaN
# 8      survived         deck                NaN          NaN              NaN
# 9      survived  embark_town                NaN          NaN              NaN
# 10     survived        alive                NaN          NaN              NaN
# 11     survived        alone                NaN          NaN              NaN
# 12       pclass          sex                NaN          NaN              NaN
# 13       pclass        sibsp                NaN          NaN              NaN
# 14       pclass        parch                NaN          NaN              NaN
# 15       pclass     embarked                NaN          NaN              NaN
# 16       pclass        class                NaN          NaN              NaN
# 17       pclass          who                NaN          NaN              NaN
# 18       pclass   adult_male                NaN          NaN              NaN
# 19       pclass         deck                NaN          NaN              NaN
# 20       pclass  embark_town                NaN          NaN              NaN
# 21       pclass        alive                NaN          NaN              NaN
# 22       pclass        alone                NaN          NaN              NaN
# 23          sex        sibsp                NaN          NaN              NaN
# 24          sex        parch                NaN          NaN              NaN
# 25          sex     embarked                NaN          NaN              NaN
# 26          sex        class                NaN          NaN              NaN
# 27          sex          who                NaN          NaN              NaN
# 28          sex   adult_male                NaN          NaN              NaN
# 29          sex         deck                NaN          NaN              NaN
# 30          sex  embark_town                NaN          NaN              NaN
# 31          sex        alive                NaN          NaN              NaN
# 32          sex        alone                NaN          NaN              NaN
# 33        sibsp        parch                NaN          NaN              NaN
# 34        sibsp     embarked                NaN          NaN              NaN
# 35        sibsp        class                NaN          NaN              NaN
# 36        sibsp          who                NaN          NaN              NaN
# 37        sibsp   adult_male                NaN          NaN              NaN
# 38        sibsp         deck                NaN          NaN              NaN
# 39        sibsp  embark_town                NaN          NaN              NaN
# 40        sibsp        alive                NaN          NaN              NaN
# 41        sibsp        alone                NaN          NaN              NaN
# 42        parch     embarked                NaN          NaN              NaN
# 43        parch        class                NaN          NaN              NaN
# 44        parch          who                NaN          NaN              NaN
# 45        parch   adult_male                NaN          NaN              NaN
# 46        parch         deck                NaN          NaN              NaN
# 47        parch  embark_town                NaN          NaN              NaN
# 48        parch        alive                NaN          NaN              NaN
# 49        parch        alone                NaN          NaN              NaN
# 50     embarked        class                NaN          NaN              NaN
# 51     embarked          who                NaN          NaN              NaN
# 52     embarked   adult_male                NaN          NaN              NaN
# 53     embarked         deck                NaN          NaN              NaN
# 54     embarked  embark_town                NaN          NaN              NaN
# 55     embarked        alive                NaN          NaN              NaN
# 56     embarked        alone                NaN          NaN              NaN
# 57        class          who                NaN          NaN              NaN
# 58        class   adult_male                NaN          NaN              NaN
# 59        class         deck                NaN          NaN              NaN
# 60        class  embark_town                NaN          NaN              NaN
# 61        class        alive                NaN          NaN              NaN
# 62        class        alone                NaN          NaN              NaN
# 63          who   adult_male                NaN          NaN              NaN
# 64          who         deck                NaN          NaN              NaN
# 65          who  embark_town                NaN          NaN              NaN
# 66          who        alive                NaN          NaN              NaN
# 67          who        alone                NaN          NaN              NaN
# 68   adult_male         deck                NaN          NaN              NaN
# 69   adult_male  embark_town                NaN          NaN              NaN
# 70   adult_male        alive                NaN          NaN              NaN
# 71   adult_male        alone                NaN          NaN              NaN
# 72         deck  embark_town                NaN          NaN              NaN
# 73         deck        alive                NaN          NaN              NaN
# 74         deck        alone                NaN          NaN              NaN
# 75  embark_town        alive                NaN          NaN              NaN
# 76  embark_town        alone                NaN          NaN              NaN
# 77        alive        alone                NaN          NaN              NaN
# 0    adult_male          age                NaN          NaN              NaN
# 1    adult_male         fare                NaN          NaN              NaN
# 2    adult_male       pclass                NaN          NaN              NaN
# 3    adult_male     survived                NaN          NaN              NaN
# 4         alive          age                NaN          NaN              NaN
# 5         alive         fare                NaN          NaN              NaN
# 6         alive       pclass                NaN          NaN              NaN
# 7         alive     survived                NaN          NaN              NaN
# 8         alone          age                NaN          NaN              NaN
# 9         alone         fare                NaN          NaN              NaN
# 10        alone       pclass                NaN          NaN              NaN
# 11        alone     survived                NaN          NaN              NaN
# 12        class          age                NaN          NaN              NaN
# 13        class         fare                NaN          NaN              NaN
# 14        class       pclass                NaN          NaN              NaN
# 15        class     survived                NaN          NaN              NaN
# 16         deck          age                NaN          NaN              NaN
# 17         deck         fare                NaN          NaN              NaN
# 18         deck       pclass                NaN          NaN              NaN
# 19         deck     survived                NaN          NaN              NaN
# 20  embark_town          age                NaN          NaN              NaN
# 21  embark_town         fare                NaN          NaN              NaN
# 22  embark_town       pclass                NaN          NaN              NaN
# 23  embark_town     survived                NaN          NaN              NaN
# 24     embarked          age                NaN          NaN              NaN
# 25     embarked         fare                NaN          NaN              NaN
# 26     embarked       pclass                NaN          NaN              NaN
# 27     embarked     survived                NaN          NaN              NaN
# 28        parch          age                NaN          NaN              NaN
# 29        parch         fare                NaN          NaN              NaN
# 30        parch       pclass                NaN          NaN              NaN
# 31        parch     survived                NaN          NaN              NaN
# 32       pclass          age                NaN          NaN              NaN
# 33       pclass         fare                NaN          NaN              NaN
# 34       pclass     survived                NaN          NaN              NaN
# 35          sex          age                NaN          NaN              NaN
# 36          sex         fare                NaN          NaN              NaN
# 37          sex       pclass                NaN          NaN              NaN
# 38          sex     survived                NaN          NaN              NaN
# 39        sibsp          age                NaN          NaN              NaN
# 40        sibsp         fare                NaN          NaN              NaN
# 41        sibsp       pclass                NaN          NaN              NaN
# 42        sibsp     survived                NaN          NaN              NaN
# 43     survived          age                NaN          NaN              NaN
# 44     survived         fare                NaN          NaN              NaN
# 45     survived       pclass                NaN          NaN              NaN
# 46          who          age                NaN          NaN              NaN
# 47          who         fare                NaN          NaN              NaN
# 48          who       pclass                NaN          NaN              NaN
# 49          who     survived                NaN          NaN              NaN
#
#     pps12  pps21 depend_chi2 subsamples_diff_dist  max_bhatta_dist
# 0    0.01   0.00         NaN                  NaN              NaN
# 1    0.00   0.00         NaN                  NaN              NaN
# 2    0.00   0.11         NaN                  NaN              NaN
# 3    0.07   0.10         NaN                  NaN              NaN
# 4    0.22   0.90         NaN                  NaN              NaN
# 5    0.00   0.00         NaN                  NaN              NaN
# 0    0.01   0.00        True                  NaN              NaN
# 1    0.52   0.13        True                  NaN              NaN
# 2    0.00   0.00        True                  NaN              NaN
# 3    0.00   0.00        True                  NaN              NaN
# 4    0.00   0.00        True                  NaN              NaN
# 5    0.19   0.00        True                  NaN              NaN
# 6    0.42   0.16        True                  NaN              NaN
# 7    0.54   0.15        True                  NaN              NaN
# 8    0.00   0.00       False                  NaN              NaN
# 9    0.00   0.00        True                  NaN              NaN
# 10   1.00   1.00        True                  NaN              NaN
# 11   0.16   0.00        True                  NaN              NaN
# 12   0.00   0.00        True                  NaN              NaN
# 13   0.00   0.00        True                  NaN              NaN
# 14   0.00   0.00       False                  NaN              NaN
# 15   0.00   0.00        True                  NaN              NaN
# 16   1.00   1.00        True                  NaN              NaN
# 17   0.00   0.00        True                  NaN              NaN
# 18   0.00   0.00        True                  NaN              NaN
# 19   0.00   0.00        True                  NaN              NaN
# 20   0.00   0.00        True                  NaN              NaN
# 21   0.24   0.01        True                  NaN              NaN
# 22   0.00   0.00        True                  NaN              NaN
# 23   0.00   0.00        True                  NaN              NaN
# 24   0.00   0.00        True                  NaN              NaN
# 25   0.00   0.00        True                  NaN              NaN
# 26   0.00   0.00        True                  NaN              NaN
# 27   0.74   0.89        True                  NaN              NaN
# 28   0.90   0.90        True                  NaN              NaN
# 29   0.00   0.07       False                  NaN              NaN
# 30   0.00   0.00        True                  NaN              NaN
# 31   0.53   0.52        True                  NaN              NaN
# 32   0.27   0.27        True                  NaN              NaN
# 33   0.00   0.00        True                  NaN              NaN
# 34   0.00   0.00        True                  NaN              NaN
# 35   0.00   0.00        True                  NaN              NaN
# 36   0.00   0.00        True                  NaN              NaN
# 37   0.00   0.00        True                  NaN              NaN
# 38   0.00   0.00       False                  NaN              NaN
# 39   0.00   0.00        True                  NaN              NaN
# 40   0.00   0.00        True                  NaN              NaN
# 41   0.00   0.00        True                  NaN              NaN
# 42   0.00   0.00        True                  NaN              NaN
# 43   0.00   0.00       False                  NaN              NaN
# 44   0.00   0.00        True                  NaN              NaN
# 45   0.00   0.00        True                  NaN              NaN
# 46   0.00   0.00       False                  NaN              NaN
# 47   0.00   0.00        True                  NaN              NaN
# 48   0.00   0.00        True                  NaN              NaN
# 49   0.00   0.00        True                  NaN              NaN
# 50   0.16   0.00        True                  NaN              NaN
# 51   0.02   0.00        True                  NaN              NaN
# 52   0.00   0.00        True                  NaN              NaN
# 53   0.00   0.04       False                  NaN              NaN
# 54   1.00   1.00        True                  NaN              NaN
# 55   0.12   0.00        True                  NaN              NaN
# 56   0.00   0.00        True                  NaN              NaN
# 57   0.00   0.00        True                  NaN              NaN
# 58   0.00   0.00        True                  NaN              NaN
# 59   0.00   0.00        True                  NaN              NaN
# 60   0.00   0.16        True                  NaN              NaN
# 61   0.24   0.19        True                  NaN              NaN
# 62   0.00   0.00        True                  NaN              NaN
# 63   1.00   0.74        True                  NaN              NaN
# 64   0.00   0.00        True                  NaN              NaN
# 65   0.00   0.02        True                  NaN              NaN
# 66   0.55   0.42        True                  NaN              NaN
# 67   0.37   0.24        True                  NaN              NaN
# 68   0.00   0.00       False                  NaN              NaN
# 69   0.00   0.00        True                  NaN              NaN
# 70   0.55   0.54        True                  NaN              NaN
# 71   0.37   0.38        True                  NaN              NaN
# 72   0.04   0.00       False                  NaN              NaN
# 73   0.03   0.00       False                  NaN              NaN
# 74   0.14   0.00       False                  NaN              NaN
# 75   0.12   0.00        True                  NaN              NaN
# 76   0.00   0.00        True                  NaN              NaN
# 77   0.16   0.09        True                  NaN              NaN
# 0    0.01   0.18         NaN                 True             0.15
# 1    0.00   0.25         NaN                 True             0.09
# 2    0.00   0.00         NaN                 True             0.48
# 3    0.15   0.54         NaN                 True             0.85
# 4    0.00   0.07         NaN                False             0.03
# 5    0.00   0.24         NaN                 True             0.06
# 6    0.01   0.24         NaN                 True             0.53
# 7    1.00   1.00         NaN                 True              NaN
# 8    0.00   0.17         NaN                 True             0.12
# 9    0.14   0.72         NaN                 True             0.32
# 10   0.00   0.00         NaN                 True             0.49
# 11   0.00   0.16         NaN                 True             0.68
# 12   0.07   0.21         NaN                 True             0.15
# 13   0.18   0.86         NaN                 True             1.17
# 14   1.00   1.00         NaN                 True              NaN
# 15   0.00   0.19         NaN                 True             0.74
# 16   0.00   0.08         NaN                 True             0.29
# 17   0.00   0.30         NaN                 True             0.66
# 18   0.00   0.00         NaN                 True              NaN
# 19   0.00   0.00         NaN                False             0.69
# 20   0.00   0.08         NaN                False             0.14
# 21   0.00   0.68         NaN                 True             0.28
# 22   0.00   0.00         NaN                 True             0.99
# 23   0.00   0.00         NaN                 True             0.68
# 24   0.00   0.08         NaN                False             0.14
# 25   0.00   0.68         NaN                 True             0.28
# 26   0.00   0.00         NaN                 True             0.99
# 27   0.00   0.00         NaN                 True             0.68
# 28   0.00   0.00         NaN                 True             2.25
# 29   0.00   0.00         NaN                 True             1.80
# 30   0.00   0.00         NaN                False             1.89
# 31   0.00   0.00         NaN                 True             0.73
# 32   0.07   0.08         NaN                 True             0.15
# 33   0.18   0.83         NaN                 True             1.17
# 34   0.00   0.01         NaN                 True             0.74
# 35   0.00   0.00         NaN                False             0.03
# 36   0.00   0.15         NaN                 True             0.07
# 37   0.00   0.00         NaN                 True             0.48
# 38   0.13   0.52         NaN                 True             0.84
# 39   0.00   0.00         NaN                 True             1.28
# 40   0.00   0.00         NaN                 True             1.58
# 41   0.00   0.00         NaN                 True             1.95
# 42   0.00   0.00         NaN                 True             0.78
# 43   0.00   0.00         NaN                False             0.03
# 44   0.00   0.00         NaN                 True             0.06
# 45   0.01   0.00         NaN                 True             0.53
# 46   0.19   0.24         NaN                 True             3.01
# 47   0.00   0.14         NaN                 True             0.25
# 48   0.00   0.00         NaN                 True             0.54
# 49   0.16   0.42         NaN                 True             0.87

# %% [markdown]
# ### missing values

# %%
eda.missing(data)

# %% [markdown]
# ### outliers analysis

# %%
eda.outliers(data)

# %% [markdown]
# ### duplicates

# %%
eda.duplicates(data, subset=[])
# Out:
# INFO: Number of duplicates for subset ['survived'] = 889 / 99.78 %
# INFO: Number of duplicates for subset ['pclass'] = 888 / 99.66 %
# INFO: Number of duplicates for subset ['sex'] = 889 / 99.78 %
# INFO: Number of duplicates for subset ['age'] = 808 / 90.68 %
# INFO: Number of duplicates for subset ['sibsp'] = 884 / 99.21 %
# INFO: Number of duplicates for subset ['parch'] = 884 / 99.21 %
# INFO: Number of duplicates for subset ['fare'] = 687 / 77.1 %
# INFO: Number of duplicates for subset ['embarked'] = 887 / 99.55 %
# INFO: Number of duplicates for subset ['class'] = 888 / 99.66 %
# INFO: Number of duplicates for subset ['who'] = 888 / 99.66 %
# INFO: Number of duplicates for subset ['adult_male'] = 889 / 99.78 %
# INFO: Number of duplicates for subset ['deck'] = 883 / 99.1 %
# INFO: Number of duplicates for subset ['embark_town'] = 887 / 99.55 %
# INFO: Number of duplicates for subset ['alive'] = 889 / 99.78 %
# INFO: Number of duplicates for subset ['alone'] = 889 / 99.78 %
# INFO: Number of duplicates for ALL columns = 112 / 12.57 %
# INFO: Number of duplicates for subset ['survived' 'sex' 'adult_male' 'alive' 'alone'] = 880 / 98.77 %
